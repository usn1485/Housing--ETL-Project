# %%
Raw_House_Data = "Scraped_houses.csv"
house_df = pd.read_csv(Raw_House_Data)
house_df.head()
# Out:
#    Unnamed: 0  Property Types     Price       Street Addresses        City  \
# 0           0  House for Sale  $279,900  147 Country Creek Ct,     Ballwin
# 1           1  House for Sale  $350,000    349 Cherry Hill Dr,  Ellisville
# 2           2  House for Sale  $340,000       402 Baberton Dr,     Ballwin
# 3           3  House for Sale  $319,900      302 Wildbrier Dr,     Ballwin
# 4           4  House for Sale  $199,900       607 Morewood Ct,  Manchester
#
#   State  Zipcode Sqft Area Beds Baths  \
# 0    MO    63011     2,001    3   2.5
# 1    MO    63011     2,397    3   2.5
# 2    MO    63011     2,419    4   2.5
# 3    MO    63011     2,319    5     2
# 4    MO    63011     1,376    3     2
#
#                                                Links
# 0  https://www.realtor.com//realestateandhomes-de...
# 1  https://www.realtor.com//realestateandhomes-de...
# 2  https://www.realtor.com//realestateandhomes-de...
# 3  https://www.realtor.com//realestateandhomes-de...
# 4  https://www.realtor.com//realestateandhomes-de...

# %%
house_df["Price"]=[x[1:] for x in house_df["Price"]]
house_df["Price"]=[x.replace(',','') for x in house_df["Price"]]
house_df["Sqft Area"]=[x.replace(',','') for x in house_df["Sqft Area"]]
house_df.head()
# Out:
#    Unnamed: 0  Property Types   Price       Street Addresses        City  \
# 0           0  House for Sale  279900  147 Country Creek Ct,     Ballwin
# 1           1  House for Sale  350000    349 Cherry Hill Dr,  Ellisville
# 2           2  House for Sale  340000       402 Baberton Dr,     Ballwin
# 3           3  House for Sale  319900      302 Wildbrier Dr,     Ballwin
# 4           4  House for Sale  199900       607 Morewood Ct,  Manchester
#
#   State  Zipcode Sqft Area Beds Baths  \
# 0    MO    63011      2001    3   2.5
# 1    MO    63011      2397    3   2.5
# 2    MO    63011      2419    4   2.5
# 3    MO    63011      2319    5     2
# 4    MO    63011      1376    3     2
#
#                                                Links
# 0  https://www.realtor.com//realestateandhomes-de...
# 1  https://www.realtor.com//realestateandhomes-de...
# 2  https://www.realtor.com//realestateandhomes-de...
# 3  https://www.realtor.com//realestateandhomes-de...
# 4  https://www.realtor.com//realestateandhomes-de...

# %%
house_df["Price"]=house_df["Price"].astype(float)
house_df["Sqft Area"]=house_df["Sqft Area"].astype(float)

# %%
house_df["Price/Sqft"]=round(house_df["Price"]/house_df["Sqft Area"],2)
#house_df=house_df.round({"Price/Sqft":2})
house_df.head()
# Out:
#    Unnamed: 0  Property Types     Price       Street Addresses        City  \
# 0           0  House for Sale  279900.0  147 Country Creek Ct,     Ballwin
# 1           1  House for Sale  350000.0    349 Cherry Hill Dr,  Ellisville
# 2           2  House for Sale  340000.0       402 Baberton Dr,     Ballwin
# 3           3  House for Sale  319900.0      302 Wildbrier Dr,     Ballwin
# 4           4  House for Sale  199900.0       607 Morewood Ct,  Manchester
#
#   State  Zipcode  Sqft Area Beds Baths  \
# 0    MO    63011     2001.0    3   2.5
# 1    MO    63011     2397.0    3   2.5
# 2    MO    63011     2419.0    4   2.5
# 3    MO    63011     2319.0    5     2
# 4    MO    63011     1376.0    3     2
#
#                                                Links  Price/Sqft
# 0  https://www.realtor.com//realestateandhomes-de...      139.88
# 1  https://www.realtor.com//realestateandhomes-de...      146.02
# 2  https://www.realtor.com//realestateandhomes-de...      140.55
# 3  https://www.realtor.com//realestateandhomes-de...      137.95
# 4  https://www.realtor.com//realestateandhomes-de...      145.28

# %%
house_data_df=house_df[["Property Types","Zipcode","Price/Sqft"]].copy()
house_data_df.head()
# Out:
#    Property Types  Zipcode  Price/Sqft
# 0  House for Sale    63011      139.88
# 1  House for Sale    63011      146.02
# 2  House for Sale    63011      140.55
# 3  House for Sale    63011      137.95
# 4  House for Sale    63011      145.28
